# %% [markdown]
# **Mount My Google Drive**

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# **Import Important Libraries**

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
from sklearn import preprocessing

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# **Data Collection**

# %%
train = pd.read_csv('gdrive/My Drive/Colab Notebooks/football_hackathon/data/raw/train.csv')
test  = pd.read_csv('gdrive/My Drive/Colab Notebooks/football_hackathon/data/raw/test.csv')

# %%
train.describe()

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20453 entries, 0 to 20452
# Columns: 800 entries, row_id to team2_offensive_derived_var_19
# dtypes: float64(794), int64(4), object(2)
# memory usage: 124.8+ MB

# %%
train_numerical_features   = train.select_dtypes(exclude='object')
train_categorical_features = train.select_dtypes(include='object')

# %%
#list of columns that are categorical
cat_f = list(train_categorical_features.columns)

# %%
cat_f
# Out:
# ['winner', 'team']

# %% [markdown]
# **Data Cleaning**

# %% [markdown]
# *Missing Data Imputation*

# %%
train.isnull().sum()
# Out:
# row_id                               0
# scout_id                             0
# rating_num                           0
# winner                               0
# team                                 0
#                                   ...
# team2_defensive_derived_var_15    1427
# team2_offensive_derived_var_16    1427
# team2_defensive_derived_var_17    1427
# team2_offensive_derived_var_18    1427
# team2_offensive_derived_var_19    1427
# Length: 800, dtype: int64

# %%
sum(train.isnull().sum())
# Out:
# 2192476

# %%
train.isnull().sum().sort_values(ascending=False)
# Out:
# team2_other_raw_var_19    20453
# team1_other_raw_var_50    20453
# team1_other_raw_var_72    20453
# team1_other_raw_var_19    20453
# team1_other_raw_var_31    20453
#                           ...
# player_general_var_2          0
# player_general_var_3          0
# player_general_var_5          0
# scout_id                      0
# row_id                        0
# Length: 800, dtype: int64

# %%
train = train.dropna()

# %% [markdown]
# **Exploratory Data Analysis**

# %% [markdown]
# **Data Transformation**

# %%
le = preprocessing.LabelEncoder()
for column_name in train.columns:
    if train[column_name].dtype == object:
       train[column_name] = le.fit_transform(train[column_name])
    else:
        pass

# %% [markdown]
# **Feature Selection**

# %% [markdown]
# **Feature Engineering**

# %% [markdown]
# **Distribution of Independent Variables**

# %% [markdown]
# **Data Splitting**

# %%
y = train['rating_num']

# %%
train['rating_num']
# Out:
# Series([], Name: rating_num, dtype: float64)

# %%
X = train.drop(['row_id','player_general_var_1','scout_id','rating_num'], axis = 1)

# %%
#Split dataset into train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.4)

# %% [markdown]
# **Data Modeling**

# %%
regressor = RandomForestRegressor(n_estimators=20, random_state=0)
regressor.fit(X_train, y_train)

# %% [markdown]
# **Hyperparameter Tuning**

# %% [markdown]
# **Prediction**

# %%
y_pred = regressor.predict(X_test)

# %% [markdown]
# **AutoML**
